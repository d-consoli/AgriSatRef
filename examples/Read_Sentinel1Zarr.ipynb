# %%
# pip install zarr
# pip install xarray
# pip install matplotlib

import xarray
import matplotlib

# %%
zarr_path = r'...\AgriSatRef\tests\data\output_zarr\WRg_32632_FRIEN_20200902_59.zarr'

# %% [raw]
# import shutil
#
# # Create a proper archive (ZIP format)
# shutil.make_archive(zarr_path, "zip", zarr_path)

# %%
# read zarr file
ds = xarray.open_dataset(zarr_path, engine="zarr", decode_cf=False)
ds
# Out:
# <xarray.Dataset> Size: 209kB
# Dimensions:      (time: 5, y: 63, x: 75)
# Coordinates:
#   * time         (time) int64 40B 0 85859 217494 303460 518358
#   * x            (x) float64 600B 6.334e+05 6.334e+05 ... 6.339e+05 6.339e+05
#   * y            (y) float64 504B 5.646e+06 5.646e+06 ... 5.645e+06 5.645e+06
# Data variables:
#     VH           (time, y, x) float32 94kB ...
#     VV           (time, y, x) float32 94kB ...
#     fid_mask     (y, x) float32 19kB ...
#     orb          (time) <U3 60B ...
#     orb_rel      (time) <U1 20B ...
#     sensor       (time) <U3 60B ...
#     spatial_ref  int64 8B ...

# %%
ds['VV'].isel(time=1).plot()
