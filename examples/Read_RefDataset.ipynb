# %%
# pip install zarr
# pip install xarray
# pip install matplotlib

import xarray
import matplotlib

# %%
zarr_path = r'...\AgriSatRef\tests\ref_dataset\UAVmask_mean_32632_FRIEN_WRg.zarr'

# %%
ds = xarray.open_dataset(zarr_path)
ds
# Out:
# <xarray.Dataset> Size: 719kB
# Dimensions:                           (y: 63, x: 75, time: 1)
# Coordinates:
#     spatial_ref                       int64 8B ...
#   * time                              (time) object 8B '20200902'
#   * x                                 (x) float64 600B 6.334e+05 ... 6.339e+05
#   * y                                 (y) float64 504B 5.646e+06 ... 5.645e+06
# Data variables: (12/19)
#     QC_FE_over_time                   (y, x) float64 38kB ...
#     QC_FE_per_time_step               (time, y, x) float64 38kB ...
#     QC_MAE_over_time                  (y, x) float64 38kB ...
#     QC_MAE_per_time_step              (time, y, x) float64 38kB ...
#     QC_RMSE_over_time                 (y, x) float64 38kB ...
#     QC_RMSE_per_time_step             (time, y, x) float64 38kB ...
#     ...                                ...
#     dry_crop                          (time, y, x) float64 38kB ...
# ...

# %%
ds['vital_crop'].plot()

# %%
ds['QC_RMSE_over_time'].plot()
